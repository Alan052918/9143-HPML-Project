# %% [markdown]
# # Validation Loss Results Using Different Gradient Descent Optimization Algorithms

# %%
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## StepLR

# %%
adadelta_step = []
with open("svoice-training-results/adadelta-step/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        adadelta_step.append(d["best"])

# print(adadelta_step)

# %%
adagrad_step = []
with open("svoice-training-results/adagrad-step/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        adagrad_step.append(d["best"])

# print(adagrad_step)

# %%
adam_step = []
with open("svoice-training-results/adam-step/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        adam_step.append(d["best"])

# print(adam_step)

# %%
rmsprop_step = []
with open("svoice-training-results/rmsprop-step/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        rmsprop_step.append(d["best"])

# print(rmsprop_step)

# %%
sgd_step = []
with open("svoice-training-results/sgd-step/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        sgd_step.append(d["best"])

# print(sgd_step)

# %%
plt.plot(adadelta_step, label="Adadelta")
plt.plot(adagrad_step, label="Adagrad")
plt.plot(adam_step, label="Adam")
plt.plot(rmsprop_step, label="RMSProp")
plt.plot(sgd_step, label="SGD")
plt.xlabel("Epoch")
plt.ylabel("Valid loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Plateau

# %%
adadelta_plateau = []
with open("svoice-training-results/adadelta-plateau/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        adadelta_plateau.append(d["best"])

# print(adadelta_plateau)

# %%
adagrad_plateau = []
with open("svoice-training-results/adagrad-plateau/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        adagrad_plateau.append(d["best"])

# print(adagrad_plateau)

# %%
adam_plateau = []
with open("svoice-training-results/adam-plateau/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        adam_plateau.append(d["best"])

# print(adam_plateau)

# %%
rmsprop_plateau = []
with open("svoice-training-results/rmsprop-plateau/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        rmsprop_plateau.append(d["best"])

# print(rmsprop_plateau)

# %%
sgd_plateau = []
with open("svoice-training-results/sgd-plateau/history.json", "r") as f:
    data = json.load(f)
    for d in data:
        sgd_plateau.append(d["best"])

# print(sgd_plateau)

# %%
plt.plot(adadelta_plateau, label="Adadelta")
plt.plot(adagrad_plateau, label="Adagrad")
plt.plot(adam_plateau, label="Adam")
plt.plot(rmsprop_plateau, label="RMSProp")
plt.plot(sgd_plateau, label="SGD")
plt.xlabel("Epoch")
plt.ylabel("Valid loss")
plt.legend()
plt.show()
